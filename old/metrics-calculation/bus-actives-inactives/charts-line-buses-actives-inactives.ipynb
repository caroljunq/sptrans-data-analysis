# %%
# Line Charts describing number of active/inactive buses each day in October 2015

# %%
import pandas as pd
import datetime
import matplotlib as plt
plt.rcParams.update({'figure.max_open_warning': 50})

# %%
# Active buses per day in october 2015
# df_total_ativos = pd.DataFrame([[],[]],columns=['hour', 'onibus'])
# df_total_inativos = pd.DataFrame([[],[]],columns=['hour', 'onibus'])
# ativos = [0 for _ in range(24)]
# inativos = [0 for _ in range(24)]
# from day 1 to day 31
for i in range(1,32):
    df_inactives = pd.read_csv(f"s3://mobility-traces-bus-sp-processed/MO_1510{i}_bus_inativos_2.csv")
#     for hour in range(0,24):
#         ativos[hour] += df_ativos['onibus'][hour]
#         inativos[hour] += df_inativos['onibus'][hour]
    weekday = datetime.datetime(2015, 10, i).weekday()
    day = dias_semana[weekday]
    df_inactives.sort_values("hour").plot(x = "hour", y = "onibus",title=f"Ônibus Inativos - {i}/10/2015 - {day}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-6dfa9ca817fb> in <module>
#       6 # from day 1 to day 31
#       7 for i in range(1,32):
# ----> 8     df_inactives = pd.read_csv(f"s3://mobility-traces-bus-sp-processed/MO_1510{i}_bus_inativos_2.csv")
#       9 #     for hour in range(0,24):
#      10 #         ativos[hour] += df_ativos['onibus'][hour]
#
# ...

# %%
# Active buses per day in october 2015
for i in range(1,32):
    df_actives = pd.read_csv(f"s3://mobility-traces-bus-sp/MO_1510{i}_bus_ativos_2.csv")
#     for hour in range(0,24):
#         ativos[hour] += df_ativos['onibus'][hour]
#         inativos[hour] += df_inativos['onibus'][hour]
    weekday = datetime.datetime(2015, 10, i).weekday()
    day = dias_semana[weekday]
    df_actives.sort_values("hour").plot(x = "hour", y = "onibus",title=f"Ônibus Ativos - {i}/10/2015 - {day}")

# %%
# df_total_ativos = pd.DataFrame({'hour': hours, 'onibus': mean_ativos})
# df_total_inativos = pd.DataFrame({'hour': hours, 'onibus': mean_inativos})

# %%
# df_total_inativos.sort_values("hour").plot(x = "hour", y = "onibus")

# %%
# df_total_ativos.sort_values("hour").plot(x = "hour", y = "onibus")
