# %% [markdown]
# # Vehicle Degree charts

# %%
# Vehicle Degree 1 - hour
import matplotlib.pyplot as plt
import pandas as pd

days_to_analyze = [1,5,4,17,12,20]

for day in days_to_analyze:

    df_degree_per_bus_graph = pd.read_parquet(f"../metrics-calculation/using-new-map-matching-filter/connectivity-metrics/connections-degree-per-minute-one-hour/MO_1510{day}/")\
        .sort_values(by=["time"])

    ax = df_degree_per_bus_graph.plot(x ="time",y = "avg_degree",title=f"Average node degree - {day}/10/2015",figsize=(15,8))
    # x axis label
    ax.set_xlabel("hour",size=20)
    # y axis label
    ax.set_ylabel("Average node degree",size=20)
    
    # title fontsize
    ax.title.set_size(20)
    plt.grid(True)
    # size of the number in both axis
    ax.tick_params(axis='both', which='major', labelsize=15)
    
    ax.get_figure().savefig(f'./charts-results-new-shape-filter/one-hour-filter-day-{day}-degree-vehicles.png',bbox_inches='tight')
    plt.close()

# %%
# Vehicle Degree - 30 min
import matplotlib.pyplot as plt
import pandas as pd

days_to_analyze = [1,5,4,17,12,20]

for day in days_to_analyze:

    df_degree_per_bus_graph = pd.read_parquet(f"../metrics-calculation/using-new-map-matching-filter/connectivity-metrics/connections-degree-per-minute-30-min/MO_1510{day}/")\
        .sort_values(by=["time"])

    ax = df_degree_per_bus_graph.plot(x ="time",y = "avg_degree",title=f"Average node degree - {day}/10/2015",figsize=(15,8))
    # x axis label
    ax.set_xlabel("hour",size=20)
    # y axis label
    ax.set_ylabel("Average node degree",size=20)
    
    # title fontsize
    ax.title.set_size(20)
    plt.grid(True)
    # size of the number in both axis
    ax.tick_params(axis='both', which='major', labelsize=15)
    
    ax.get_figure().savefig(f'./charts-results-new-shape-filter/30-min-filter-day-{day}-degree-vehicles.png',bbox_inches='tight')
    plt.close()

# %%
# Vehicle Degree - 15 min - count 1
import matplotlib.pyplot as plt
import pandas as pd

days_to_analyze = [1,5,4,17,12,20]

for day in days_to_analyze:

    df_degree_per_bus_graph = pd.read_parquet(f"../metrics-calculation/using-new-map-matching-filter/connectivity-metrics/connections-degree-per-minute-15-min-count-1/MO_1510{day}/")\
        .sort_values(by=["time"])

    ax = df_degree_per_bus_graph.plot(x ="time",y = "avg_degree",title=f"Average node degree - {day}/10/2015",figsize=(15,8))
    # x axis label
    ax.set_xlabel("hour",size=20)
    # y axis label
    ax.set_ylabel("Average node degree",size=20)
    
    # title fontsize
    ax.title.set_size(20)
    plt.grid(True)
    # size of the number in both axis
    ax.tick_params(axis='both', which='major', labelsize=15)
    
    ax.get_figure().savefig(f'./charts-results-new-shape-filter/15-min-filter-count-1-day-{day}-degree-vehicles.png',bbox_inches='tight')
    plt.close()

# %%
# Vehicle Degree - 15 min - count 2 or 1
import matplotlib.pyplot as plt
import pandas as pd

days_to_analyze = [1,5,4,17,12,20]

for day in days_to_analyze:

    df_degree_per_bus_graph = pd.read_parquet(f"../metrics-calculation/using-new-map-matching-filter/connectivity-metrics/connections-degree-per-minute-15-min-count-2-or-1/MO_1510{day}/")\
        .sort_values(by=["time"])

    ax = df_degree_per_bus_graph.plot(x ="time",y = "avg_degree",title=f"Average node degree - {day}/10/2015",figsize=(15,8))
    # x axis label
    ax.set_xlabel("hour",size=20)
    # y axis label
    ax.set_ylabel("Average node degree",size=20)
    
    # title fontsize
    ax.title.set_size(20)
    plt.grid(True)
    # size of the number in both axis
    ax.tick_params(axis='both', which='major', labelsize=15)
    
    ax.get_figure().savefig(f'./charts-results-new-shape-filter/15-min-filter-count-2-or-1-day-{day}-degree-vehicles.png',bbox_inches='tight')
    plt.close()

# %% [markdown]
# # ECDF - Vehicle Degree

# %%
# ECDF connectivy degree - 1 hour
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt


days_to_analyze = [1,5,4,17,12,20]

for day in days_to_analyze:

    df = pd.read_parquet(f"../metrics-calculation/using-new-map-matching-filter/connectivity-metrics/connections-per-vehicle-per-graph-one-hour/MO_1510{day}/")


    x= np.sort(df["number_connections"])
    y= np.arange(1,len(x)+1) / len(x)
    plt.plot(x,y,marker=".",linestyle="none")
    ax = plt.gca()
    plt.margins(0.02)

    ax.set_xlabel("number of connections",size=15)
    # y axis label
    ax.set_ylabel("ECDF",size=15)

    #title fontsize
    ax.title.set_size(20)
    plt.grid(True)
    # size of the number in both axis
    ax.tick_params(axis='both', which='major', labelsize=15)
    plt.savefig(f"./charts-results-new-shape-filter/one-hour-connections-degree-ecdf-day-{day}.png",dpi=300)
    plt.close()

# %%
# ECDF connectivy degree - 15min count 1 or 2
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt


days_to_analyze = [1,5,4,17,12,20]

for day in days_to_analyze:

    df = pd.read_parquet(f"../metrics-calculation/using-new-map-matching-filter/connectivity-metrics/connections-per-vehicle-per-graph-15-min-count-2-or-1/MO_1510{day}/")


    x= np.sort(df["number_connections"])
    y= np.arange(1,len(x)+1) / len(x)
    plt.plot(x,y,marker=".",linestyle="none")
    ax = plt.gca()
    plt.margins(0.02)

    ax.set_xlabel("number of connections",size=15)
    # y axis label
    ax.set_ylabel("ECDF",size=15)

    #title fontsize
    ax.title.set_size(20)
    plt.grid(True)
    # size of the number in both axis
    ax.tick_params(axis='both', which='major', labelsize=15)
    plt.savefig(f"./charts-results-new-shape-filter/15-min-count-2-or-1-connections-degree-ecdf-day-{day}.png",dpi=300)
    plt.close()

# %%
# ECDF connectivy degree - 15min count 1
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt


days_to_analyze = [1,5,4,17,12,20]

for day in days_to_analyze:

    df = pd.read_parquet(f"../metrics-calculation/using-new-map-matching-filter/connectivity-metrics/connections-per-vehicle-per-graph-15-min-count-1/MO_1510{day}/")


    x= np.sort(df["number_connections"])
    y= np.arange(1,len(x)+1) / len(x)
    plt.plot(x,y,marker=".",linestyle="none")
    ax = plt.gca()
    plt.margins(0.02)

    ax.set_xlabel("number of connections",size=15)
    # y axis label
    ax.set_ylabel("ECDF",size=15)

    #title fontsize
    ax.title.set_size(20)
    plt.grid(True)
    # size of the number in both axis
    ax.tick_params(axis='both', which='major', labelsize=15)
    plt.savefig(f"./charts-results-new-shape-filter/15-min-count-1-connections-degree-ecdf-day-{day}.png",dpi=300)
    plt.close()

# %% [markdown]
# # Repeated Connections

# %%
# Histogram repeated connections - 1 Hour

import matplotlib.pyplot as plt
import pandas as pd

days_to_analyze = [1,5,4,17,12,20]

for day in days_to_analyze:

    df = pd.read_parquet(f"../metrics-calculation/using-new-map-matching-filter/connectivity-metrics/repeated-connection-per-day-one-hour/MO_1510{day}/")
    ax = df["count_per_day"].plot.hist(logy=True,figsize=(10,10),bins=20)
    plt.grid(True)
    ax.set_xlabel("repeated connections",size=20)
    ax.set_ylabel("frequency",size=20)
    plt.title(f"Histogram repeated connections {day}/10/2015",size=20)
    plt.savefig(f'./charts-results-new-shape-filter/one-hour-repeated-conn-historgram-total-{day}.png',bbox_inches='tight')
    plt.close()

# %%
# Histogram repeated connections - 15min count 1

import matplotlib.pyplot as plt
import pandas as pd

days_to_analyze = [1,5,4,17,12,20]

for day in days_to_analyze:

    df = pd.read_parquet(f"../metrics-calculation/using-new-map-matching-filter/connectivity-metrics/repeated-connection-per-day-15-min-count-1/MO_1510{day}/")
    ax = df["count_per_day"].plot.hist(logy=True,figsize=(10,10),bins=20)
    plt.grid(True)
    ax.set_xlabel("repeated connections",size=20)
    ax.set_ylabel("frequency",size=20)
    plt.title(f"Histogram repeated connections {day}/10/2015",size=20)
    plt.savefig(f'./charts-results-new-shape-filter/15-min-count-1-repeated-conn-historgram-total-{day}.png',bbox_inches='tight')
    plt.close()

# %%
# Histogram repeated connections - 15min count 2 or 1

import matplotlib.pyplot as plt
import pandas as pd

days_to_analyze = [1,5,4,17,12,20]

for day in days_to_analyze:

    df = pd.read_parquet(f"../metrics-calculation/using-new-map-matching-filter/connectivity-metrics/repeated-connection-per-day-15-min-count-2-or-1/MO_1510{day}/")
    ax = df["count_per_day"].plot.hist(logy=True,figsize=(10,10),bins=20)
    plt.grid(True)
    ax.set_xlabel("repeated connections",size=20)
    ax.set_ylabel("frequency",size=20)
    plt.title(f"Histogram repeated connections {day}/10/2015",size=20)
    plt.savefig(f'./charts-results-new-shape-filter/15-min-count-2-or-1-repeated-conn-historgram-total-{day}.png',bbox_inches='tight')
    plt.close()

# %%
# ECDF Repeated Connections - 1 Hour

import numpy as np

days_to_analyze = [1,5,4,17,12,20]

for day in days_to_analyze:
    
    df = pd.read_parquet(f"../metrics-calculation/using-new-map-matching-filter/connectivity-metrics/repeated-connection-per-day-one-hour/MO_1510{day}/")

    x = np.sort(df["count_per_day"])
    
    y = np.arange(1,len(x)+1) / len(x)
    
    plt.title(f"ECDF Repeated Connection - {day}/10/2015",size=15)
    
    _ = plt.plot(x,y,marker=".",linestyle="none")
    
    plt.margins(0.02)
    plt.savefig(f'./charts-results-new-shape-filter/one-hour-ecdf-repeated-connections-{day}.png',bbox_inches='tight')
    plt.close()

# %%
# ECDF Repeated Connections - 15min count 1

import numpy as np

days_to_analyze = [1,5,4,17,12,20]

for day in days_to_analyze:
    
    df = pd.read_parquet(f"../metrics-calculation/using-new-map-matching-filter/connectivity-metrics/repeated-connection-per-day-15-min-count-1/MO_1510{day}/")

    x = np.sort(df["count_per_day"])
    
    y = np.arange(1,len(x)+1) / len(x)
    
    plt.title(f"ECDF Repeated Connection - {day}/10/2015",size=15)
    
    _ = plt.plot(x,y,marker=".",linestyle="none")
    
    plt.margins(0.02)
    plt.savefig(f'./charts-results-new-shape-filter/15-min-count-1-ecdf-repeated-connections-{day}.png',bbox_inches='tight')
    plt.close()

# %%
# ECDF Repeated Connections - 15min count 2 or 1

import numpy as np

days_to_analyze = [1,5,4,17,12,20]

for day in days_to_analyze:
    
    df = pd.read_parquet(f"../metrics-calculation/using-new-map-matching-filter/connectivity-metrics/repeated-connection-per-day-15-min-count-2-or-1/MO_1510{day}/")

    x = np.sort(df["count_per_day"])
    
    y = np.arange(1,len(x)+1) / len(x)
    
    plt.title(f"ECDF Repeated Connection - {day}/10/2015",size=15)
    
    _ = plt.plot(x,y,marker=".",linestyle="none")
    
    plt.margins(0.02)
    plt.savefig(f'./charts-results-new-shape-filter/15-min-count-2-or-1-ecdf-repeated-connections-{day}.png',bbox_inches='tight')
    plt.close()

# %% [markdown]
# # Speed Charts

# %%
# average speed per hour per day - 1 hour
import pandas as pd
import matplotlib.pyplot as plt

days_to_analyze = [1,5,4,17,12,20]

for day in days_to_analyze:

    speed_per_hour = pd.read_parquet(f"../metrics-calculation/using-new-map-matching-filter/speed-calculation/speed-per-hour-per-day-one-hour-filter/MO_1510{day}/").sort_values(by=["hour_avl"])

    ax = speed_per_hour.plot(x="hour_avl",y ="avg_speed",title=f"Average speed per hour - {day}/10/2015",figsize=(10,8))
    # x axis label
    ax.set_xlabel("hour",size=20)
    # y axis label
    ax.set_ylabel("Avg speed (km/h)",size=20)
    # Setting x axis ticks
#     plt.xticks([hour for hour in range(6,23)])
    # Title size
    ax.title.set_size(20)

    # size of the number in both axis
    ax.tick_params(axis='both', which='major', labelsize=20)
    plt.grid(True)

    # saving chart as png
    ax.get_figure().savefig(f'./charts-results-new-shape-filter/avg-speed-per-hour-day-{day}-10-2015-one-hour.png',bbox_inches='tight')
    plt.close()

# %%
# average speed per hour per day - 15 min count 2 or 1
import pandas as pd
import matplotlib.pyplot as plt

days_to_analyze = [1,5,4,17,12,20]

for day in days_to_analyze:

    speed_per_hour = pd.read_parquet(f"../metrics-calculation/using-new-map-matching-filter/speed-calculation/speed-per-hour-per-day-15-min-count-2-or-1/MO_1510{day}/").sort_values(by=["hour_avl"])

    ax = speed_per_hour.plot(x="hour_avl",y ="avg_speed",title=f"Average speed per hour - {day}/10/2015",figsize=(10,8))
    # x axis label
    ax.set_xlabel("hour",size=20)
    # y axis label
    ax.set_ylabel("Avg speed (km/h)",size=20)
    # Setting x axis ticks
#     plt.xticks([hour for hour in range(6,23)])
    # Title size
    ax.title.set_size(20)

    # size of the number in both axis
    ax.tick_params(axis='both', which='major', labelsize=20)
    plt.grid(True)

    # saving chart as png
    ax.get_figure().savefig(f'./charts-results-new-shape-filter/avg-speed-per-hour-day-{day}-10-2015--15-min-count-2-or-1.png',bbox_inches='tight')
    plt.close()

# %%
# ECDF Speed per vehicle 1 Hour

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_parquet(f"../metrics-calculation/using-new-map-matching-filter/speed-calculation/speed-per-vehicle-one-hour-filter/MO_15101/")


x= np.sort(df["avg_speed"])
y= np.arange(1,len(x)+1) / len(x)
plt.plot(x,y,marker=".",linestyle="none")
ax = plt.gca()
plt.margins(0.02)

ax.set_xlabel("velocidade média (km/h)",size=15)
# y axis label
ax.set_ylabel("ECDF",size=15)

#title fontsize
ax.title.set_size(20)
plt.grid(True)
# size of the number in both axis
ax.tick_params(axis='both', which='major', labelsize=15)
# plt.savefig("./charts-results/speed-ecdf-1-10.png",dpi=300)

# %%
# ECDF Speed per vehicle 15min count 2 or 1

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_parquet(f"../metrics-calculation/using-new-map-matching-filter/speed-calculation/speed-per-vehicle-15-min-filter-count-2-or-1/MO_15101/")


x= np.sort(df["avg_speed"])
y= np.arange(1,len(x)+1) / len(x)
plt.plot(x,y,marker=".",linestyle="none")
ax = plt.gca()
plt.margins(0.02)

ax.set_xlabel("velocidade média (km/h)",size=15)
# y axis label
ax.set_ylabel("ECDF",size=15)

#title fontsize
ax.title.set_size(20)
plt.grid(True)
# size of the number in both axis
ax.tick_params(axis='both', which='major', labelsize=15)
# plt.savefig("./charts-results/speed-ecdf-1-10.png",dpi=300)

# %% [markdown]
# # Active buses

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Buses per hour per day - 1 hour

days_to_analyze = [1,5,4,17,12,20]

for day in days_to_analyze:
    
    df_hour_day = pd.read_parquet(f"../metrics-calculation/using-new-map-matching-filter/actives-buses/active-buses-per-hour-one-hour-filter/MO_1510{day}/").sort_values(by=["hour_avl"])
    ax = df_hour_day.plot(x ="hour_avl",y = "number_buses",title=f"Número de ônibus ativos por hora no dia {day}/10/2015",figsize=(8,6))
    # x axis label
    ax.set_xlabel("hora",size=15)
    # y axis label
    ax.set_ylabel("ônibus ativos",size=15)
    #plt.xticks([hour for hour in range(6,23)])
    # size of the number in both axis
    ax.tick_params(axis='both', which='major', labelsize=15)
    # title fontsize
    ax.title.set_size(15)
    plt.grid(True)
    # saving chart as png
    ax.get_figure().savefig(f'./charts-results-new-shape-filter/one-hour-actives-bus-per-hour-{day}-10-2015.png')
    plt.close()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Buses per hour per day - 15 min count 2 or 1

days_to_analyze = [1,5,4,17,12,20]

for day in days_to_analyze:
    
    df_hour_day = pd.read_parquet(f"../metrics-calculation/using-new-map-matching-filter/actives-buses/active-buses-per-hour-15-min-filter-2-or-1/MO_1510{day}/").sort_values(by=["hour_avl"])
    ax = df_hour_day.plot(x ="hour_avl",y = "number_buses",title=f"Número de ônibus ativos por hora no dia {day}/10/2015",figsize=(8,6))
    # x axis label
    ax.set_xlabel("hora",size=15)
    # y axis label
    ax.set_ylabel("ônibus ativos",size=15)
    #plt.xticks([hour for hour in range(6,23)])
    # size of the number in both axis
    ax.tick_params(axis='both', which='major', labelsize=15)
    # title fontsize
    ax.title.set_size(15)
    plt.grid(True)
    # saving chart as png
    ax.get_figure().savefig(f'./charts-results-new-shape-filter/15-min-count-2-or-1-actives-bus-per-hour-{day}-10-2015.png')
    plt.close()
