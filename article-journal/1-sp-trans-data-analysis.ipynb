# %%
import numpy as np
import pandas as pd
from sklearn import datasets
import matplotlib.pyplot as plt

# Visualize petal length distribution for all species
fig, ax = plt.subplots(figsize=(12, 7))

# Remove top and right border
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)# Remove y-axis tick marks
ax.yaxis.set_ticks_position('none')# Add major gridlines in the y-axis
ax.grid(color='grey', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)# Set plot title
# ax.set_title('Distribution of petal length by species')# Set species names as labels for the boxplot
# dataset = [setosa_petal_length, versicolor_petal_length, virginica_petal_length]



# df = pd.DataFrame([(6,5,12000),(6,6,12500),(6,7,12500),(6,8,12700),(6,9,13500),(7,5,12000),(7,6,12500),(7,7,12500),(7,8,12700),(7,9,13500)])
# df.columns = ["hour","day","contagem"]

# df_1 = df.loc[df["hour"] == 6]["contagem"]
# df_2 = df.loc[df["hour"] == 7]["contagem"]
dataset = []
df = pd.read_parquet("../2-metrics-calculation/metrics-calculation/using-15-min-filter/speed-calculation/speed-per-hour-all-weekdays/")

for hour in range(6,23):
    dataset.append(df.loc[df["hour_avl"] == hour]["avg_speed"])

ax.boxplot(dataset,labels=[hour for hour in range(6,23)])

plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn import datasets
import matplotlib.pyplot as plt

# Visualize petal length distribution for all species
fig, ax = plt.subplots(figsize=(12, 7))

# Remove top and right border
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)# Remove y-axis tick marks
ax.yaxis.set_ticks_position('none')# Add major gridlines in the y-axis
ax.grid(color='grey', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)# Set plot title
# ax.set_title('Distribution of petal length by species')# Set species names as labels for the boxplot
# dataset = [setosa_petal_length, versicolor_petal_length, virginica_petal_length]



# df = pd.DataFrame([(6,5,12000),(6,6,12500),(6,7,12500),(6,8,12700),(6,9,13500),(7,5,12000),(7,6,12500),(7,7,12500),(7,8,12700),(7,9,13500)])
# df.columns = ["hour","day","contagem"]

# df_1 = df.loc[df["hour"] == 6]["contagem"]
# df_2 = df.loc[df["hour"] == 7]["contagem"]
dataset = []
df = pd.read_parquet("../2-metrics-calculation/metrics-calculation/using-15-min-filter/actives-buses/active-buses-per-hour-all-weekends/")

for hour in range(6,23):
    dataset.append(df.loc[df["hour_avl"] == hour]["number_buses"])

ax.boxplot(dataset,labels=[hour for hour in range(6,23)])

plt.show()

# %%
for day in range(1,32):
df = pd.read_parquet("../2-metrics-calculation/metrics-calculation/using-15-min-filter/actives-buses/active-buses-per-hour/MO_151028/")
df.head(100)
# Out:
#     hour_avl  number_buses
# 0         18         12580
# 1         21         10305
# 2         17         12574
# 3         19         12442
# 4         22          8710
# 5          6         12491
# 6          9         12359
# 7         10         11938
# 8         12         11305
# 9         11         11510
# 10        13         11262
# 11        14         11384
# 12        15         11789
# 13         7         12854
# 14         8         12754
# 15        20         11786
# 16        16         12238
