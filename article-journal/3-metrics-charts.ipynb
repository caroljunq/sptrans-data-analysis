# %% [markdown]
# # Complementary material for the article "Characterizing a mobility dataset of buses of Sao Paulo"

# %% [markdown]
# *Authors: Carolina J. Ferreira and Hermes Senger*
#
# *University: Federal University of Sao Carlos*

# %% [markdown]
# This notebook shows the charts and values obtained for the metrics collected to characterize the dataset of this work.
#
# The dataset of this work contains mobility traces of more than 14000 buses of the city of São Paulo collected in October 2015. The dataset was provided by SpTrans a government organization which controls the organization of buses in Sao Paulo.
#
# Sao Paulo is a city with 12 million of people. The public transportation can provide usefull information and data to the area of Vehicular Networks - VANETs.
#
#
# The goal of this complementary material is to provide a descriptive view of the dataset for any interested researcher.
#
# The dataset passed by preprocessing steps to remove possible outliers (errors, stopped buses, etc.) that can affect the metrics value. These steps are described in other notebook -  - [Preprocessing Data](./1-preprocessing-data.ipynb)
#
# ### Dataset summary
# - **Number of buses:** more than 14000 buses
# - **Days coverage:** 31 days of October 2015 - 9 weekends days, 21 weekdays, and 1 holidays (October 12)
# - **Hours**: traces between 6:00 and 22:59

# %% [markdown]
# <hr style="height:1px"></hr>
#
# ## First metric: Speed of the buses
#
# This metrics represents the average speed of the buses.
#
# The average speed for a bus is calculated by the average of the instantaneous speeds for that bus. If we group the instantaneous speed of a bus in a interval of hour, we have the avg speed of that bus in some interval of time.

# %% [markdown]
# ### Avg Speed per hour - weekdays

# %%
# Data sample
import pandas as pd

df = pd.read_parquet("./metrics-calculation-data/speed-calculation/speed-per-hour-all-weekdays/")
df.head(3)
# Out:
#    hour_avl  avg_speed  speed_stddev  day
# 0        18  12.566039      3.719345    1
# 1        21  16.069306      5.164532    1
# 2        17  13.249082      3.745971    1

# %%
# Avg Speed per hour - weekdays (all the 21 weekdays)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 15})

fig, ax = plt.subplots(figsize=(12, 7))

ax.grid(color='grey', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)


dataset = []
# loading file
df = pd.read_parquet("./metrics-calculation-data/speed-calculation/speed-per-hour-all-weekdays/")

for hour in range(6,23):
    dataset.append(df.loc[df["hour_avl"] == hour]["avg_speed"])
    
    
plt.ylabel("km/h")
plt.xlabel("hour")

ax.boxplot(dataset,labels=[hour for hour in range(6,23)],medianprops=dict(color='orange',linewidth=1.5))

plt.savefig(f'./charts-results/average-speed-per-hour-on-weekdays-with-aggregation.png',bbox_inches='tight',dpi=500)

plt.title("Average speed per hour on weekdays")

plt.show()

# %% [markdown]
# ### Avg Speed per hour - weekends (saturdays and sundays) and holiday

# %%
# Data Sample
import pandas as pd

df = pd.read_parquet("./metrics-calculation-data/speed-calculation/speed-per-hour-all-weekends/")
df.head(3)
# Out:
#    hour_avl  avg_speed  speed_stddev  day
# 0        18  14.084157      4.471689    3
# 1        21  16.142491      5.306035    3
# 2        17  14.393693      4.537030    3

# %%
# Avg Speed per hour - weekends and  holiday

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 15})

fig, ax = plt.subplots(figsize=(12, 7))

ax.grid(color='grey', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)

dataset = []
# loading file
df = pd.read_parquet("./metrics-calculation-data/speed-calculation/speed-per-hour-all-weekends/")

for hour in range(6,23):
    dataset.append(df.loc[df["hour_avl"] == hour]["avg_speed"])
    
plt.ylabel("km/h")
plt.xlabel("hour")

ax.boxplot(dataset,labels=[hour for hour in range(6,23)],medianprops=dict(color='orange',linewidth=1.5))

plt.savefig(f'./charts-results/average-speed-per-hour-on-weekends-and-holiday-with-aggregation.png',bbox_inches='tight',dpi=500)

plt.title("Average speed per hour on weekends and holiday")

plt.show()

# %% [markdown]
# ### Avg Speed per hour - saturdays

# %%
# Avg Speed per hour - saturdays

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 15})

fig, ax = plt.subplots(figsize=(12, 7))

ax.grid(color='grey', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)

dataset = []
# loading file
df = pd.read_parquet("./metrics-calculation-data/speed-calculation/speed-per-hour-all-saturdays/")

for hour in range(6,23):
    dataset.append(df.loc[df["hour_avl"] == hour]["avg_speed"])

plt.ylabel("km/h")
plt.xlabel("hour")

ax.boxplot(dataset,labels=[hour for hour in range(6,23)],medianprops=dict(color='orange',linewidth=1.5))

plt.savefig(f'./charts-results/average-speed-per-hour-on-saturdays-with-aggregation.png',bbox_inches='tight',dpi=500)

plt.title("Average speed per hour on saturdays")

plt.show()

# %% [markdown]
# ### Avg Speed per hour - sundays

# %%
# Avg Speed per hour - sundays

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 15})

fig, ax = plt.subplots(figsize=(12, 7))

ax.grid(color='grey', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)

dataset = []
# loading file
df = pd.read_parquet("./metrics-calculation-data/speed-calculation/speed-per-hour-all-sundays/")

for hour in range(6,23):
    dataset.append(df.loc[df["hour_avl"] == hour]["avg_speed"])

plt.ylabel("km/h")
plt.xlabel("hour")

ax.boxplot(dataset,labels=[hour for hour in range(6,23)],medianprops=dict(color='orange',linewidth=1.5))

plt.savefig(f'./charts-results/average-speed-per-hour-on-sundays-and-holiday-with-aggregation.png',bbox_inches='tight',dpi=500)

plt.title("Average speed per hour on sundays and holiday")

plt.show()

# %% [markdown]
# ### Avg speed per vehicle per hour - weekdays

# %%
# Data Sample
df = pd.read_parquet("./metrics-calculation-data/speed-calculation/speed-per-vehicle-per-hour-all-weekdays/")
df.head(3)
# Out:
#    id_avl  hour_avl  avg_speed  speed_stddev  day
# 0   38243         6  14.208491     10.127391    1
# 1   42076        20  13.958900     10.286029    1
# 2   44462         9  12.633265     14.795820    1

# %%
# Avg speed per vehicle per hour - weekdays

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 15})

fig, ax = plt.subplots(figsize=(12, 7))

ax.grid(color='grey', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)

dataset = []
# loading file
df = pd.read_parquet("./metrics-calculation-data/speed-calculation/speed-per-vehicle-per-hour-all-weekdays/")

for hour in range(6,23):
    dataset.append(df.loc[df["hour_avl"] == hour]["avg_speed"])
    

# ax.boxplot(dataset,labels=[hour for hour in range(6,23)],medianprops=dict(color='orange',linewidth=1.5),flierprops=dict(markeredgecolor='gray',marker='x'))

ax.boxplot(dataset,labels=[hour for hour in range(6,23)],medianprops=dict(color='orange',linewidth=1.5))

plt.ylabel("km/h")
plt.xlabel("hour")

plt.savefig(f'./charts-results/avg-speed-per-vehicle-per-hour-weekdays.png',bbox_inches='tight',dpi=500)

plt.title("Average vehicle speed per hour on weekdays")

plt.show()

# %% [markdown]
# ### Avg speed per vehicle per hour - weekends and holiday

# %%
df = pd.read_parquet("./metrics-calculation-data/speed-calculation/speed-per-vehicle-per-hour-all-weekends/")
df.head(3)
# Out:
#    id_avl  hour_avl  avg_speed  speed_stddev  day
# 0   12005        19  20.780951     13.663489    3
# 1   19987        17   8.847593      9.424567    3
# 2   37109         7  16.951261     13.289151    3

# %%
# Avg speed per vehicle per hour - weekends and holiday

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 15})

fig, ax = plt.subplots(figsize=(12, 7))

ax.grid(color='grey', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)

dataset = []
# loading file
df = pd.read_parquet("./metrics-calculation-data/speed-calculation/speed-per-vehicle-per-hour-all-weekends/")

for hour in range(6,23):
    dataset.append(df.loc[df["hour_avl"] == hour]["avg_speed"])
    

# ax.boxplot(dataset,labels=[hour for hour in range(6,23)],medianprops=dict(color='orange',linewidth=1.5),flierprops=dict(markeredgecolor='gray',marker='x'))

ax.boxplot(dataset,labels=[hour for hour in range(6,23)],medianprops=dict(color='orange',linewidth=1.5))


plt.ylabel("km/h")
plt.xlabel("hour")

plt.savefig(f'./charts-results/avg-speed-per-vehicle-per-hour-weekends-holiday.png',bbox_inches='tight',dpi=500)

plt.title("Average vehicle speed per hour on weekends and holiday")

plt.show()

# %% [markdown]
# ### Avg speed per vehicle per hour - saturdays

# %%
# Avg speed per vehicle per hour - saturdays

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 15})

fig, ax = plt.subplots(figsize=(12, 7))

ax.grid(color='grey', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)

dataset = []
# loading file
df = pd.read_parquet("./metrics-calculation-data/speed-calculation/speed-per-vehicle-per-hour-all-saturdays/")

for hour in range(6,23):
    dataset.append(df.loc[df["hour_avl"] == hour]["avg_speed"])
    

# ax.boxplot(dataset,labels=[hour for hour in range(6,23)],medianprops=dict(color='orange',linewidth=1.5),flierprops=dict(markeredgecolor='gray',marker='x'))

ax.boxplot(dataset,labels=[hour for hour in range(6,23)],medianprops=dict(color='orange',linewidth=1.5))


plt.ylabel("km/h")
plt.xlabel("hour")

plt.savefig(f'./charts-results/avg-speed-per-vehicle-per-hour-saturdays.png',bbox_inches='tight',dpi=500)

plt.title("Average vehicle speed per hour on saturdays")

plt.show()

# %% [markdown]
# ### Avg speed per vehicle per hour - sundays and holiday

# %%
# Avg speed per vehicle per hour - sundays and holiday

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 15})

fig, ax = plt.subplots(figsize=(12, 7))

ax.grid(color='grey', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)

dataset = []
# loading file
df = pd.read_parquet("./metrics-calculation-data/speed-calculation/speed-per-vehicle-per-hour-all-sundays/")

for hour in range(6,23):
    dataset.append(df.loc[df["hour_avl"] == hour]["avg_speed"])
    

# ax.boxplot(dataset,labels=[hour for hour in range(6,23)],medianprops=dict(color='orange',linewidth=1.5),flierprops=dict(markeredgecolor='gray',marker='x'))

ax.boxplot(dataset,labels=[hour for hour in range(6,23)],medianprops=dict(color='orange',linewidth=1.5))


plt.ylabel("km/h")
plt.xlabel("hour")

plt.savefig(f'./charts-results/avg-speed-per-vehicle-per-hour-sundays-holiday.png',bbox_inches='tight',dpi=500)

plt.title("Average vehicle speed per hour on sundays and holiday")

plt.show()

# %% [markdown]
# ### Avg speed per vehicle per hour - weekdays - histogram

# %%
# Avg speed per vehicle per hour - weekdays

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 15})

fig, ax = plt.subplots(figsize=(12, 7))

ax.grid(color='grey', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)

dataset = []
# loading file
df = pd.read_parquet("./metrics-calculation-data/speed-calculation/speed-per-vehicle-per-hour-all-weekdays/")

# for hour in range(6,23):
#     dataset.append(df.loc[df["hour_avl"] == hour]["avg_speed"])
    

# ax.boxplot(dataset,labels=[hour for hour in range(6,23)],medianprops=dict(color='orange',linewidth=1.5),flierprops=dict(markeredgecolor='gray',marker='x'))

# ax.boxplot(dataset,labels=[hour for hour in range(6,23)])

plt.xlabel("km/h")
plt.ylabel("number of buses")
plt.yscale('log')

# plt.savefig(f'./charts-results/avg-speed-per-vehicle-per-hour-weekdays.png',bbox_inches='tight',dpi=500)

# plt.title("Average vehicle speed per hour on weekdays")

df["avg_speed"].hist(bins=20)

plt.show()

# %%
?????? Histogram or not. This chart can have repeated buses
Number of buses or number of trips???
A trip = a bus travel in one hour???

Nao so aqui mas no outros grafico de velocidade talvez chamage veiculo/hora = trip?
# Out:
#   File "<ipython-input-16-78689de2ac95>", line 2
#     Number of buses or number of trips???
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Second metric: Active buses
#
# This metrics represents how many buses are traveling by the city in a point in time.
# The buses' traces 'stopped' in the bus terminals for more than 15 min were removed.

# %% [markdown]
# ### Active buses - Weekdays

# %%
# Data Sample
df = pd.read_parquet("./metrics-calculation-data/actives-buses/active-buses-per-hour-all-weekdays/")
df.head(3)
# Out:
#    hour_avl  number_buses  day
# 0        18         12685    1
# 1        21         10533    1
# 2        17         12694    1

# %%
# Active buses - Weekdays

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 15})

fig, ax = plt.subplots(figsize=(12, 7))

ax.grid(color='grey', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)


dataset = []
df = pd.read_parquet("./metrics-calculation-data/actives-buses/active-buses-per-hour-all-weekdays/")

for hour in range(6,23):
    dataset.append(df.loc[df["hour_avl"] == hour]["number_buses"])

ax.boxplot(dataset,labels=[hour for hour in range(6,23)],medianprops=dict(color='orange',linewidth=1.5))


plt.ylabel("number of buses")
plt.xlabel("hour")

plt.savefig(f'./charts-results/active-buses-weekdays.png',bbox_inches='tight',dpi=500)

plt.title("Active buses per hour on weekdays")

plt.show()

# The number of active buses shows that bus companies' planning, 
# the low dispersion/divergence reflects the public transportation planning.

# %%
# Studying weekdays outliers for active buses per hour on weekdays
df = pd.read_parquet("./metrics-calculation-data/actives-buses/active-buses-per-hour-all-weekdays/")
df.loc[df["number_buses"] < 8000]

# day October 23 atipic day --> probably a problem with sensors position detection
# Out:
#      hour_avl  number_buses  day
# 263        12          1351   23
# 265        13          6039   23

# %% [markdown]
# ### Active buses - Weekends and holiday

# %%
# Data Sample
df = pd.read_parquet("./metrics-calculation-data/actives-buses/active-buses-per-hour-all-weekends/")
df.head(10)
# Out:
#    hour_avl  number_buses  day
# 0        18          8385    3
# 1        21          7309    3
# 2        17          8455    3
# 3        19          8278    3
# 4        22          6424    3
# 5         6          8008    3
# 6         9          8610    3
# 7        10          8579    3
# 8        12          8629    3
# 9        11          8622    3

# %%
# Active buses - Weekends and holiday

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 15})

fig, ax = plt.subplots(figsize=(12, 7))

ax.grid(color='grey', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)


dataset = []
df = pd.read_parquet("./metrics-calculation-data/actives-buses/active-buses-per-hour-all-weekends/")

for hour in range(6,23):
    dataset.append(df.loc[df["hour_avl"] == hour]["number_buses"])

ax.boxplot(dataset,labels=[hour for hour in range(6,23)],medianprops=dict(color='orange',linewidth=1.5))


plt.ylabel("number of buses")
plt.xlabel("hour")

plt.savefig(f'./charts-results/active-buses-weekends.png',bbox_inches='tight',dpi=500)

plt.title("Active buses per hour on weekends and holiday")

plt.show()

# %% [markdown]
# ### Active buses - Saturdays

# %%
# Active buses - Saturdays

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 15})

fig, ax = plt.subplots(figsize=(12, 7))

ax.grid(color='grey', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)


dataset = []
df = pd.read_parquet("./metrics-calculation-data/actives-buses/active-buses-per-hour-all-saturdays/")

for hour in range(6,23):
    dataset.append(df.loc[df["hour_avl"] == hour]["number_buses"])

ax.boxplot(dataset,labels=[hour for hour in range(6,23)],medianprops=dict(color='orange',linewidth=1.5))


plt.ylabel("number of buses")
plt.xlabel("hour")

plt.savefig(f'./charts-results/active-buses-saturdays.png',bbox_inches='tight',dpi=500)

plt.title("Active buses per hour on saturdays")

plt.show()

# %% [markdown]
# ### Active buses - Sundays and holiday

# %%
# Active buses - Sundays and holiday

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 15})

fig, ax = plt.subplots(figsize=(12, 7))

ax.grid(color='grey', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)


dataset = []
df = pd.read_parquet("./metrics-calculation-data/actives-buses/active-buses-per-hour-all-sundays/")

for hour in range(6,23):
    dataset.append(df.loc[df["hour_avl"] == hour]["number_buses"])

ax.boxplot(dataset,labels=[hour for hour in range(6,23)],medianprops=dict(color='orange',linewidth=1.5))


plt.ylabel("number of buses")
plt.xlabel("hour")

plt.savefig(f'./charts-results/active-buses-sundays.png',bbox_inches='tight',dpi=500)

plt.title("Active buses per hour on sundays and holiday")

plt.show()

# %% [markdown]
# ## Third metric: Encounters between buses
# This metrics represents the number of encounters (vehicles far up to 100 meters - vanets radies) a bus has in a point in time (hour:minute) in a region.

# %% [markdown]
# ### Vehicle encounters per hour - weekdays

# %%
# Vehicle encounters per hour - weekdays

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 15})

fig, ax = plt.subplots(figsize=(12, 7))

ax.grid(color='grey', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)


dataset = []
df = pd.read_parquet(f"./metrics-calculation-data/connectivity-metrics/all-connections-per-vehicle-per-graph-weekdays/")


for hour in range(6,23):
    dataset.append(df.loc[df["hour"] == str(hour)]["number_connections"])

minimum = min(df["number_connections"])
maximum = max(df["number_connections"])
# ax.set_yscale('log')

ax.boxplot(dataset,labels=[hour for hour in range(6,23)],medianprops=dict(color='orange',linewidth=1.5))

plt.ylabel("number of encounters")
plt.xlabel("hour")

plt.yticks(np.arange(0, maximum+1, 5.0))

plt.savefig(f'./charts-results/vehicle-encounters-per-hour-boxplot-weekdays.png',bbox_inches='tight',dpi=500)

plt.title("Vehicle Encounters per hour - weekdays")

plt.show()

# %%
from IPython.display import Image
print("                  Vehicle Encounters per hour - weekdays                 ")
Image(filename='./charts-results/vehicle-encounters-per-hour-boxplot-weekdays.png')
# Out:
#                   Vehicle Encounters per hour - weekdays

# %% [markdown]
# ### Vehicle encounters per hour - weekends and holiday

# %%
# Vehicle encounters per hour - weekends and holiday

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 15})

fig, ax = plt.subplots(figsize=(12, 7))

ax.grid(color='grey', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)


dataset = []
df = pd.read_parquet(f"./metrics-calculation-data/connectivity-metrics/all-connections-per-vehicle-per-graph-weekends/")


for hour in range(6,23):
    dataset.append(df.loc[df["hour"] == str(hour)]["number_connections"])

minimum = min(df["number_connections"])
maximum = max(df["number_connections"])
# ax.set_yscale('log')

ax.boxplot(dataset,labels=[hour for hour in range(6,23)],medianprops=dict(color='orange',linewidth=1.5))

plt.ylabel("number of encounters")
plt.xlabel("hour")

plt.yticks(np.arange(0, maximum+1, 5.0))

plt.savefig(f'./charts-results/vehicle-encounters-per-hour-boxplot-weekends.png',bbox_inches='tight',dpi=500)

plt.title("Vehicle Encounters per hour - weekends and holiday")

plt.show()

# %% [markdown]
# ### Vehicle encounters per hour - saturdays

# %%
# Vehicle encounters per hour - saturdays

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 15})

fig, ax = plt.subplots(figsize=(12, 7))

ax.grid(color='grey', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)


dataset = []
df = pd.read_parquet(f"./metrics-calculation-data/connectivity-metrics/all-connections-per-vehicle-per-graph-saturdays/")


for hour in range(6,23):
    dataset.append(df.loc[df["hour"] == str(hour)]["number_connections"])

minimum = min(df["number_connections"])
maximum = max(df["number_connections"])
# ax.set_yscale('log')

ax.boxplot(dataset,labels=[hour for hour in range(6,23)],medianprops=dict(color='orange',linewidth=1.5))

plt.ylabel("number of encounters")
plt.xlabel("hour")

plt.yticks(np.arange(0, maximum+1, 5.0))

plt.savefig(f'./charts-results/vehicle-encounters-per-hour-boxplot-saturdays.png',bbox_inches='tight',dpi=500)

plt.title("Vehicle Encounters per hour - saturdays")

plt.show()

# %% [markdown]
# ### Vehicle encounters per hour - sundays and holiday

# %%
# Vehicle Degree per minute - sundays and holiday
import pandas as pd
df = pd.read_parquet(f"./metrics-calculation-data/connectivity-metrics/all-connections-per-vehicle-per-graph-sundays/")
df.head(5)
# Out:
#    id_avl_1  number_connections           region  day hour-minute hour
# 0     36841                   2               SE   18       12:37   12
# 1     43117                   1  PARQUE DO CARMO   18       18:26   18
# 2     10916                   1          CURSINO   25       13:24   13
# 3     12789                   1       BELA VISTA   18       12:57   12
# 4     40590                   3      SANTO AMARO   25       14:35   14

# %%
# Vehicle encounters per hour - sundays and holiday

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 15})

fig, ax = plt.subplots(figsize=(12, 7))

ax.grid(color='grey', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)


dataset = []
df = pd.read_parquet(f"./metrics-calculation-data/connectivity-metrics/all-connections-per-vehicle-per-graph-sundays/")


for hour in range(6,23):
    dataset.append(df.loc[df["hour"] == str(hour)]["number_connections"])

minimum = min(df["number_connections"])
maximum = max(df["number_connections"])
# ax.set_yscale('log')

ax.boxplot(dataset,labels=[hour for hour in range(6,23)],medianprops=dict(color='orange',linewidth=1.5))

plt.ylabel("number of encounters")
plt.xlabel("hour")

plt.yticks(np.arange(0, maximum+1, 5.0))

plt.savefig(f'./charts-results/vehicle-encounters-per-hour-boxplot-sundays.png',bbox_inches='tight',dpi=500)

plt.title("Vehicle Encounters per hour - sundays and holiday")

plt.show()

# %% [markdown]
# ### Avg encounters per vehicle per minute - weekdays

# %%
# Data Sample 
import pandas as pd
df = pd.read_parquet(f"./metrics-calculation-data/connectivity-metrics/vehicle-encounters-avg-per-minute-weekdays/")\
        .sort_values(by=["hour-minute"])

df.head(5)
# Out:
#     hour-minute  avg_number_connections
# 845       06:00                3.219859
# 843       06:01                5.468998
# 163       06:02                5.507648
# 103       06:03                5.501412
# 969       06:04                5.509743

# %%
# Avg encounters per vehicle per minute - weekdays
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 15})


df = pd.read_parquet(f"./metrics-calculation-data/connectivity-metrics/vehicle-encounters-avg-per-minute-weekdays/")\
        .sort_values(by=["hour-minute"])

ax = df.plot(x ="hour-minute",y = "avg_number_connections",figsize=(12,7),label='Avg encounters')

ax.grid(color='grey', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)


# x axis label
ax.set_xlabel("hour")
# y axis label
ax.set_ylabel("average of encounters")

ax.get_figure().savefig(f'./charts-results/vehicle-encounters-avg-per-minute-weekdays.png',bbox_inches='tight',dpi=500)

plt.title("Average encounters per vehicle per minute on weekdays")
# Out:
# Text(0.5, 1, 'Average encounters per vehicle per minute on weekdays')

# %% [markdown]
# ### Avg encounters per vehicle per minute - weekends and holiday

# %%
# Avg encounters per vehicle per minute - weekends and holiday
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 15})


df = pd.read_parquet(f"./metrics-calculation-data/connectivity-metrics/vehicle-encounters-avg-per-minute-weekends/")\
        .sort_values(by=["hour-minute"])

ax = df.plot(x ="hour-minute",y = "avg_number_connections",figsize=(12,7),label='Avg encounters')

ax.grid(color='grey', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)


# x axis label
ax.set_xlabel("hour")
# y axis label
ax.set_ylabel("average of encounters")

ax.get_figure().savefig(f'./charts-results/vehicle-encounters-avg-per-minute-weekends.png',bbox_inches='tight',dpi=500)

plt.title("Average encounters per vehicle per minute on weekends and holiday")
# Out:
# Text(0.5, 1, 'Average encounters per vehicle per minute on weekends and holiday')

# %% [markdown]
# ### Avg encounters per vehicle per minute - saturdays

# %%
# Avg encounters per vehicle per minute - saturdays
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 15})


df = pd.read_parquet(f"./metrics-calculation-data/connectivity-metrics/vehicle-encounters-avg-per-minute-saturdays/")\
        .sort_values(by=["hour-minute"])

ax = df.plot(x ="hour-minute",y = "avg_number_connections",figsize=(12,7),label='Avg encounters')

ax.grid(color='grey', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)


# x axis label
ax.set_xlabel("hour")
# y axis label
ax.set_ylabel("average of encounters")

ax.get_figure().savefig(f'./charts-results/vehicle-encounters-avg-per-minute-saturdays.png',bbox_inches='tight',dpi=500)

plt.title("Average encounters per vehicle per minute on saturdays")
# Out:
# Text(0.5, 1, 'Average encounters per vehicle per minute on saturdays')

# %% [markdown]
# ### Avg encounters per vehicle per minute - sundays and holiday

# %%
# Avg encounters per vehicle per minute - sundays and holiday
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 15})


df = pd.read_parquet(f"./metrics-calculation-data/connectivity-metrics/vehicle-encounters-avg-per-minute-sundays/")\
        .sort_values(by=["hour-minute"])

ax = df.plot(x ="hour-minute",y = "avg_number_connections",figsize=(12,7),label='Avg encounters')

ax.grid(color='grey', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)


# x axis label
ax.set_xlabel("hour")
# y axis label
ax.set_ylabel("average of encounters")

ax.get_figure().savefig(f'./charts-results/vehicle-encounters-avg-per-minute-sundays.png',bbox_inches='tight',dpi=500)

plt.title("Average encounters per vehicle per minute on sundays")
# Out:
# Text(0.5, 1, 'Average encounters per vehicle per minute on sundays')

# %% [markdown]
# ### Number of encounters per vehicle histogram - weekdays

# %%
# Number of encounters per vehicle histogram - weekdays

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 15})

fig, ax = plt.subplots(figsize=(12, 7))

ax.grid(color='grey', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)

dataset = []
# loading file
df = pd.read_parquet(f"./metrics-calculation-data/connectivity-metrics/all-connections-per-vehicle-per-graph-weekdays/")


plt.ylabel("number of vehicles")
plt.xlabel("number of encounters")
plt.yscale('log')

plt.savefig(f'./charts-results/histogram-encounters-weekdays.png',bbox_inches='tight',dpi=500)

plt.title("Histogram encounters per vehicle on weekdays")

df["number_connections"].hist(bins=20)

plt.show()

# %% [markdown]
# ### Number of encounters per vehicle histogram - weekends and holiday

# %%
# Number of encounters per vehicle histogram - weekends and holiday

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 15})

fig, ax = plt.subplots(figsize=(12, 7))

ax.grid(color='grey', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)

dataset = []
# loading file
df = pd.read_parquet(f"./metrics-calculation-data/connectivity-metrics/all-connections-per-vehicle-per-graph-weekends/")


plt.ylabel("number of vehicles")
plt.xlabel("number of encounters")
plt.yscale('log')

plt.savefig(f'./charts-results/histogram-encounters-weekends.png',bbox_inches='tight',dpi=500)

plt.title("Histogram encounters per vehicle on weekends and holiday")

df["number_connections"].hist(bins=20)

plt.show()

# %% [markdown]
# ### Number of encounters per vehicle histogram - saturdays

# %%
# Number of encounters per vehicle histogram - saturdays

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 15})

fig, ax = plt.subplots(figsize=(12, 7))

ax.grid(color='grey', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)

dataset = []
# loading file
df = pd.read_parquet(f"./metrics-calculation-data/connectivity-metrics/all-connections-per-vehicle-per-graph-saturdays/")


plt.ylabel("number of vehicles")
plt.xlabel("number of encounters")
plt.yscale('log')

plt.savefig(f'./charts-results/histogram-encounters-saturdays.png',bbox_inches='tight',dpi=500)

plt.title("Histogram encounters per vehicle on saturdays")

df["number_connections"].hist(bins=29)

plt.show()

# %% [markdown]
# ### Number of encounters per vehicle histogram - sundays and holiday

# %%
# Number of encounters per vehicle histogram - sundays and holiday

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 15})

fig, ax = plt.subplots(figsize=(12, 7))

ax.grid(color='grey', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)

dataset = []
# loading file
df = pd.read_parquet(f"./metrics-calculation-data/connectivity-metrics/all-connections-per-vehicle-per-graph-sundays/")


plt.ylabel("number of vehicles")
plt.xlabel("number of encounters")
plt.yscale('log')

plt.savefig(f'./charts-results/histogram-encounters-sundays.png',bbox_inches='tight',dpi=500)

plt.title("Histogram encounters per vehicle on sundays and holiday")

df["number_connections"].hist(bins=25)

plt.show()

# %%
fazer curva de distribuicao??

# %%
- Consigo passar o eixo vertical para base 10?
- opcoes: tabela ou escala exponencial
    
- colocar serrilhado com média(media tem problema, 
pois representa agregacao distorce a informação, pra isso foi feito o boxplot). Explicar outlier do boxplot --> sao onibus que pode estar parados por um periodo de tempo dentro dos terminais
- escrever no notebook, todos os gráficos no notebook
- o que é a métrica, como foi calculada, pq ela acontece (onibus parado, outliers)


- ir colocando descricoes nas celulas do notebook
- dar acabamento nos gráficos e eliminar comentarios/código nao pertinente
- colocar figuras no overleaf, e breve descrição
# Out:
#   File "<ipython-input-8-0b40c068407c>", line 1
#     - Consigo passar o eixo vertical para base 10?
#                    ^
# SyntaxError: invalid syntax
